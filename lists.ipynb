# %%
n=0
m=1
p=23
matchs = [23,56, 12,24]
for wickests in matchs:
  
    
  n=n+wickests
  m=m*wickests
  

  print(wickests)
print("Sum of the list is : ",n)
print("Multiplication of the list is : ",m)
# Out:
# 23
# 56
# 12
# 24
# Sum of the list is :  115
# Multiplication of the list is :  370944
# Smaller of the list is :  56

# %%
for wickests in matchs:
  if wickests<p:
    p=wickests
print("Smallest Number of the lists: ",p)
# Out:
# Smallest Number of the lists:  12

# %%
#Slicing
#Same as done before in the 

print(matchs[0:2])

print(matchs[:])

print(matchs[-1])

n
# Out:
# [23, 56]
# [23, 56, 12, 24]
# 24

# %%
#List Methods 
p=matchs.pop(23)
print(p)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-81b684f363ef> in <module>
#       1 #List Methods
# ----> 2 p=matchs.pop(23)
#       3 print(p)
#
# IndexError: pop index out of range
