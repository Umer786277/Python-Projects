# %%
#Loops

i=1
while i<=5:
  print(i) 
  i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while i<=5:
  print(i * "*") 
  i=i+1
# Out:
# *
# **
# ***
# ****
# *****

# %%
i=5
while i>=1:
  print(i * "*") 
  i=i-1
# Out:
# *****
# ****
# ***
# **
# *

# %%
i=1
sum=0
while i<=5:
  print(i)
  sum=sum+i
  avg=sum/5
 
  i=i+1
print("Sum of first 5 Natural Numbers is :", sum) 
print("Average of first 5 Natural Numbers is :", avg)
# Out:
# 1
# 2
# 3
# 4
# 5
# Sum of first 5 Natural Numbers is : 15
# Average of first 5 Natural Numbers is : 3.0

# %%
i=1

while i<=5:
  print("Number is ", i ,"and the cube of",i ,"is :" ,i**3)

  

 
  i=i+1
# Out:
# Number is  1 and the cube of 1 is : 1
# Number is  2 and the cube of 2 is : 8
# Number is  3 and the cube of 3 is : 27
# Number is  4 and the cube of 4 is : 64
# Number is  5 and the cube of 5 is : 125

# %%
#Find the Facttorial
n=1
m=1
while n<=5:
  m=m*n
  n=n+1

print("Factorial is: ",m)
# Out:
# Factorial is:  120

# %%
from binascii import b2a_qp
#Count the even and odd Numbers in 1 to 10 Natural Numbers

i=1
n=0
p=0
for i in range(10):
  if i%2==0:
    n=n+1
    b=i
    print("Even Numbers are: ",b)
    
  elif i%2!=0:
    p=p+1
    s=i
    print("Odd Numbers are: ",s)
print("Total Even Numbers are: ",n)
print("Total Odd Numbers are: ", p)
# Out:
# Even Numbers are:  0
# Odd Numbers are:  1
# Even Numbers are:  2
# Odd Numbers are:  3
# Even Numbers are:  4
# Odd Numbers are:  5
# Even Numbers are:  6
# Odd Numbers are:  7
# Even Numbers are:  8
# Odd Numbers are:  9
# Total Even Numbers are:  5
# Total Odd Numbers are:  5

# %%
n=5
for  i in range(n):
  for j in range(i):
   print ('* ', end="")
  print('')

for  i in range(n,0,-1):
  for j in range(i):
    print ('* ', end="")
  print('')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
# Print Any Table Of Your Requirement

i=1
n=int(input("Enter Number of Table: "))
while i<=10:
  print(i, "*", n, "=", i*n )
  i=i+1
# Out:
# Enter Number of Table: 4
# 1 * 4 = 4
# 2 * 4 = 8
# 3 * 4 = 12
# 4 * 4 = 16
# 5 * 4 = 20
# 6 * 4 = 24
# 7 * 4 = 28
# 8 * 4 = 32
# 9 * 4 = 36
# 10 * 4 = 40

# %%
n=input("Enter Word: ")
m=""
m=n
print(m[::-1])
# Out:
# Enter Word: musali
# ilasum
